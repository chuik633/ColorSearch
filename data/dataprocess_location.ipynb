# %%
import pandas as pd
df = pd.read_json('./df_colorImage.json')
print(df.head())
# Out:
#                                            title  \
# 0           Brown hat with pheasant feather brim
# 1                      Green conical crochet hat
# 2  Lavender tweed skirt designed by Arthur McGee
# 3                   Straw hat with upturned brim
# 4                               Blue suede beret
#
#                                   id  \
# 0  ld1-1729331898832-1729331901604-1
# 1  ld1-1726829471747-1726829474245-0
# 2  ld1-1643398738600-1643398742572-0
# 3  ld1-1729331898832-1729331901613-0
# 4  ld1-1729331898832-1729331901615-0
#
#                                          data_source  \
# 0  National Museum of African American History an...
# 1  National Museum of African American History an...
# 2  National Museum of African American History an...
# 3  National Museum of African American History an...
# 4  National Museum of African American History an...
#
#                                        record_link  \
# 0   https://nmaahc.si.edu/object/nmaahc_2007.3.568
# ...

# %%
places = df['place'].to_list()
unique_places = []
for place_lst in places:
    if place_lst != None and place_lst not in unique_places:
        for place in place_lst:
            if place  not in unique_places:
                unique_places.append(place)

# import pprint
# pprint.pprint(unique_places)

# %%
known_places = {
    "New York City": {"lat": 40.7128, "long": -74.0060},
    # "United States": {"lat": 37.0902, "long": -95.7129},
    "Saint Louis": {"lat": 38.6270, "long": -90.1994},
    "Missouri": {"lat": 38.5739, "long": -92.6038},
    "Chicago": {"lat": 41.8781, "long": -87.6298},
    "New York": {"lat": 40.7128, "long": -74.0060},
    "Florence": {"lat": 43.7696, "long": 11.2558},
    "Italy": {"lat": 41.8719, "long": 12.5674},
    "Tokyo": {"lat": 35.6762, "long": 139.6503},
    "Paris": {"lat": 48.8566, "long": 2.3522},
    "London": {"lat": 51.5074, "long": -0.1278},
    "Berlin": {"lat": 52.5200, "long": 13.4050},
    "Spain": {"lat": 40.4637, "long": -3.7492},
    "Brussels": {"lat": 50.8503, "long": 4.3517},
    "Philadelphia": {"lat": 39.9526, "long": -75.1652},
    "Los Angeles": {"lat": 34.0522, "long": -118.2437},
    "Miami": {"lat": 25.7617, "long": -80.1918},
    "Detroit": {"lat": 42.3314, "long": -83.0458},
    "Paris": {"lat": 48.8566, "long": 2.3522},
    "Dallas": {"lat": 32.7767, "long": -96.7970},
    "San Francisco": {"lat": 37.7749, "long": -122.4194},
    "Oakland": {"lat": 37.8044, "long": -122.2711},
    "Tokyo": {"lat": 35.6762, "long": 139.6503},
    "Chennai": {"lat": 13.0827, "long": 80.2707},
    "Brazil": {"lat": -14.2350, "long": -51.9253},
    # "North and Central America": {"lat": 21.9187, "long": -95.5126},
    "Auburn": {"lat": 42.9262, "long": -76.5483},
    "Cayuga County": {"lat": 42.7651, "long": -76.5650},
    "Illinois": {"lat": 40.6331, "long": -89.3985},
    "Cook County": {"lat": 41.7378, "long": -87.6976},
    "Gibson County": {"lat": 38.3537, "long": -87.3664},
    "Indiana": {"lat": 40.2672, "long": -86.1349},
    "Lyles Station": {"lat": 38.3207, "long": -87.4023},
    "Harrison County": {"lat": 38.1419, "long": -86.8495},
    "Texas": {"lat": 31.9686, "long": -99.9018},
    "Marshall": {"lat": 32.5532, "long": -94.3663},
    "Georgia": {"lat": 33.6407, "long": -83.4416},
    "Little Rock": {"lat": 34.7465, "long": -92.2896},
    "Arkansas": {"lat": 34.7465, "long": -92.2896},
    "Pulaski County": {"lat": 34.8202, "long": -92.3083},
    "Tuscany": {"lat": 43.7712, "long": 11.2486},
    "South America": {"lat": -8.7832, "long": -55.4915},
    "Bahia": {"lat": -12.5780, "long": -41.5016},
    "Latin America": {"lat": 20.0000, "long": -75.0000},
    "Massachusetts": {"lat": 42.4072, "long": -71.3824},
    "Easthampton": {"lat": 42.2654, "long": -72.6697},
    "China": {"lat": 35.8617, "long": 104.1954},
    "Kota": {"lat": 25.2138, "long": 75.8648},
    "Rajasthan state": {"lat": 27.0238, "long": 74.2179},
    "India": {"lat": 20.5937, "long": 78.9629},
    "Prince George County": {"lat": 38.7849, "long": -76.9094},
    "Accokeek": {"lat": 38.7043, "long": -77.0666},
    "Maryland": {"lat": 39.0458, "long": -76.6413},
    "Martha's Vineyard": {"lat": 41.4030, "long": -70.6053},
    "Oak Bluffs": {"lat": 41.4550, "long": -70.5558},
    "Duke County": {"lat": 41.3134, "long": -70.5563},
    "Japan": {"lat": 36.2048, "long": 138.2529},
    "Sumter County": {"lat": 32.0207, "long": -80.3977},
    "Alabama": {"lat": 32.8067, "long": -86.7911},
    "Wayne County": {"lat": 42.2226, "long": -83.0082},
    "Michigan": {"lat": 44.3148, "long": -85.6024},
    "Waterproof": {"lat": 31.2490, "long": -91.4700},
    "Tensas Parish": {"lat": 31.8234, "long": -91.4165},
    "Louisiana": {"lat": 30.9843, "long": -91.9623},
    "West Feliciana Parish": {"lat": 30.8004, "long": -91.3980},
    "Angola": {"lat": -11.2027, "long": 17.8739},
    "Rosewood": {"lat": 30.4293, "long": -81.6496},
    "Levy County": {"lat": 29.1304, "long": -82.4590},
    "Florida": {"lat": 27.9944, "long": -81.7603},
    "Mississippi": {"lat": 32.7416, "long": -89.6787},
    "Madison County": {"lat": 38.7283, "long": -88.5721},
    "Canton": {"lat": 33.3072, "long": -81.0728},
    "Baltimore": {"lat": 39.2904, "long": -76.6122},
    "Guler": {"lat": 32.2642, "long": 77.5625},
    "Himachal Pradesh state": {"lat": 32.0504, "long": 77.2190},
    "Ferguson": {"lat": 38.7369, "long": -90.3045},
    "Saint Louis County": {"lat": 38.6103, "long": -90.4125},
    "Colorado": {"lat": 39.5501, "long": -105.7821},
    "Denver": {"lat": 39.7392, "long": -104.9903},
    "Kansas": {"lat": 39.0119, "long": -98.4842},
    "Caldwell": {"lat": 30.9176, "long": -97.7431},
    "District of Columbia": {"lat": 38.9072, "long": -77.0369},
    "Washington": {"lat": 47.7511, "long": -120.7401},
    "Ocala National Forest": {"lat": 29.1872, "long": -81.8178},
    "Cleveland National Forest": {"lat": 33.6874, "long": -116.9406},
    "Siskiyou County": {"lat": 41.4090, "long": -122.2526},
    "California": {"lat": 36.7783, "long": -119.4179},
    "Klamath National Forest": {"lat": 41.7036, "long": -122.4987},
    "San Diego County": {"lat": 33.0676, "long": -116.7467},
    "Humboldt-Toiyabe National Forest": {"lat": 39.5676, "long": -119.6380},
    "Nevada": {"lat": 38.8026, "long": -116.4194},
    "Owo": {"lat": 7.2085, "long": 5.5734},
    "Nigeria": {"lat": 9.0820, "long": 8.6753},
    "Claiborne Parish": {"lat": 32.7797, "long": -92.6501},
    "Pennsylvania": {"lat": 41.2033, "long": -77.1945},
    "Asia": {"lat": 34.0479, "long": 100.6197},
    "Guadeloupe": {"lat": 16.9954, "long": -62.0675},
    "Tamil Nadu": {"lat": 11.1271, "long": 78.6569},
    "Pointe-à-Pitre": {"lat": 16.2395, "long": -61.5310},
    "Grande-Terre": {"lat": 16.3035, "long": -61.5310},
    "Caribbean": {"lat": 15.0000, "long": -75.0000},
    "Madras": {"lat": 13.0827, "long": 80.2707},
    "Europe": {"lat": 54.5260, "long": 15.2551},
    "Alameda County": {"lat": 37.6013, "long": -122.2697},
    "France": {"lat": 46.6034, "long": 1.8883},
    "England": {"lat": 52.3555, "long": -1.1743},
    "USA": {"lat": 37.0902, "long": -95.7129},
    "Haiti": {"lat": 18.9712, "long": -72.2852},
    "Connecticut": {"lat": 41.6032, "long": -73.0877},
    "Anne Arundel County": {"lat": 38.9784, "long": -76.4922},
    "Highland Beach": {"lat": 26.4093, "long": -80.0764},
    "Île-de-France": {"lat": 48.8566, "long": 2.3522},
    "Newport": {"lat": 41.4901, "long": -71.3128},
    "Rhode Island": {"lat": 41.6809, "long": -71.5118},
    "Mantua": {"lat": 45.1457, "long": 10.7037},
    "Watford": {"lat": 51.6576, "long": -0.3971},
    "Cassiobury Estate": {"lat": 51.6544, "long": -0.4047},
    "1600 Pennsylvania Ave NW": {"lat": 38.8977, "long": -77.0365},
    "Stonington": {"lat": 41.3540, "long": -71.9041},
    "Amesbury": {"lat": 42.8502, "long": -70.9340},
    "Dallas County": {"lat": 32.8035, "long": -96.8276},
    "Selma": {"lat": 32.4073, "long": -87.0226},
    "Weimar": {"lat": 51.0302, "long": 11.3297},
    "Germany": {"lat": 51.1657, "long": 10.4515},
    "Montgomery": {"lat": 32.3668, "long": -86.3000},
    "Harlem": {"lat": 40.8115, "long": -73.9465},
    "Leesburg": {"lat": 39.1157, "long": -77.5636},
    "Loudoun County": {"lat": 39.1036, "long": -77.6532},
    "Virginia": {"lat": 37.4316, "long": -78.6569},
    "Staunton": {"lat": 38.1499, "long": -79.0705},
    "Augusta County": {"lat": 38.2078, "long": -79.2453},
    "Belgium": {"lat": 50.8503, "long": 4.3517},
    "Netherlands": {"lat": 52.1326, "long": 5.2913},
    "Manhattan County": {"lat": 40.7831, "long": -73.9712},
    "Studio City": {"lat": 34.1392, "long": -118.3927}

}

# %%
for place in unique_places:
    if place not in known_places.keys():
        print(place)
# Out:
# United States
# North and Central America

# %%
df = df.dropna(subset=['place'])
# # import pprint
# # pprint.pprint(df['place'].to_list())
# df.loc[:, 'place'] = df['place'].apply(lambda x: x[0] if isinstance(x, list) else x)

def get_lat_lon_from_known_places(places_list):
    if places_list is None:  
        return None, None
    for place in places_list:
        if place in known_places.keys():

            return known_places[place]['lat'], known_places[place]['long']
    return None, None
df[['latitude', 'longitude']] = df['place'].apply(lambda x: pd.Series(get_lat_lon_from_known_places(x)))

# %%
df = df.dropna(subset=['latitude'])
df.head()
# Out:
#                                               title  \
# 2     Lavender tweed skirt designed by Arthur McGee
# 7         Taupe wool skirt designed by Arthur McGee
# 8    Grey pinstriped skirt designed by Arthur McGee
# 9   Dark grey velvet dress designed by Arthur McGee
# 10             Denim skirt designed by Arthur McGee
#
#                                    id  \
# 2   ld1-1643398738600-1643398742572-0
# 7   ld1-1643398738600-1643398742580-0
# 8   ld1-1643398738600-1643398742579-0
# 9   ld1-1643398738600-1643398742578-0
# 10  ld1-1664883611343-1664883614645-0
#
#                                           data_source  \
# 2   National Museum of African American History an...
# 7   National Museum of African American History an...
# 8   National Museum of African American History an...
# 9   National Museum of African American History an...
# 10  National Museum of African American History an...
#
#                                         record_link  \
# ...

# %%
df.to_json('df_location.json', orient="records", indent=4)
